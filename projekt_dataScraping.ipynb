# %% [markdown]
# # Projekt Data Scraping (SS 21) – Großbritannien oder NYT

# %%
from IPython.display import IFrame
IFrame('https://nytimes.com', width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://nytimes.com"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Was ist das Projekt? Was ist das Ziel?
#
# Im Projekt soll geprüft werden, wie und über was in der amerikanischen Medienlandschaft berichtet wird. Dazu werden zunächst Daten von der API der (liberalen/pro-Dem.) **New York Times** in Anspruch genommen. Hier gibt es dreierlei Zugriff:
#
# + Zugriff auf **Most Popular Articles API**
#     - Erklärung auf der Dokumentationsseite: "Provides services for getting the most popular articles on NYTimes.com based on emails, shares, or views."
#
# + Zugriff auf **Article Search API**
#     - Erklärung auf der Dokumentationsseite: "Use the Article Search API to look up articles by keyword. You can refine your search using filters and facets."
#
# + Zugriff auf **Article Archive API**
#     - Erklärung auf der Dokumentationsseite: "The Archive API returns an array of NYT articles for a given month, going back to 1851."
#
# + Zugrif auf **Top Stories API**
#     - Erklärung auf der Dokumentationsseite: "The Top Stories API returns an array of articles currently on the specified section (arts, business, ...)."
#
# Vergleichend dazu könnte ein **eher konservatives News-Portal gegenübergestellt** werden, um zu sehen, welche Artikel dort im Trend liegen. Da auch in den meisten Fällen die Schlagzeilen verfügbar sein sollten, könnte man hier sehen, was bei der jeweiligen Leserschaft dieser Zeitungen im Trend liegt.
#
# Das Ziel ist dann, herauszustellen, **ob sich zwischen Zeitungen/News-Outlets mit einer liberalen, pro-Democrats Leserschaft und jenen mit einer konservativen, pro-Republican Leserschaft klare Unterschiede** feststellen lassen, was beispielsweise...:
#
# + ... die Themen der News-Artikel angeht
#
# + ... die Sprache in den Schlagzeilen der populärsten News-Artikel angeht
#
# Eine weitere Frage, die man aus den Daten heraus angehen könnte, wäre auch, ob es möglicherweise News-Trends gibt, die besonders in einer der beiden untersuchten Portale thematisiert werden – in der anderen jedoch gar nicht.
#
# Mittels den Möglichkeiten in Richtung Article Search oder Article Archive könnte man darüber hinaus einen festgelegten Zeitraum einstellen (z. B. einen Monat oder auch mehr). Danach könnte dann untersucht werden, welche "Tags" für die Artikel in diesem Zeitraum dominant waren oder auch, welche Ressorts vorwiegend von den jeweils unterschiedlichen Nachrichtenseiten im gleichen Zeitraum bedient wurden.
#
# *So könnte man versuchen, weitere bzw. andere Trends festzustellen: werden in konservativen Nachrichtenquellen mehr/öfter/mit höherer Frequenz Politik-Themen besprochen? Oder kommen dazu mehr in den liberalen Nachrichtenquellen?*

# %% [markdown]
# ## Woher bekommt man die Daten?
#
# Die Daten für die ***NYT sind über eine eingerichtete API mittels API-Key*** verfügbar. Ein solcher Key wurde schon beantragt, getestet und ist einsatzbereit.
#
# Für eine zweite Quelle käme evtl. die ***Developer-Version der Currents-API*** infrage, ein kurzer Blick hierauf kann über die folgende Zelle erlangt werden. Ein Vorteil wäre hier auch, dass eine Suche, einem ersten Blick zufolge, nicht nur auf Nachrichten im klassischen Sinne begrenzt wäre, sondern innerhalb der gleichen API-Sortierungsmöglichkeiten wie bei der NYT, auch Blogs o. Ä. durchsuchbar machen würde. Und gerade im konservativen Nachrichtenspektrum der USA sind diese auch oft eine Informations- und Nachrichtenquelle für viele Menschen.

# %%
IFrame('https://currentsapi.services/en', width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://currentsapi.services/en"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Ist Scraping legal?
#
# + **NYT**: Der Zugang ist legal, da er mittels API-Key erfolgt und somit von der NYT selbst freigeschaltet wurde.
#
# + Auch im Falle von **Currents** erfolgt der Zugang über einen API-Key, ist damit legal. Jedoch gibt es hier einen Cap von 600 Newsartikeln/Tag. Ob dies ausreichend sein wird, muss noch erprobt werden.
#
# Weitere Alternativen zu Currents wären [mediastack](https://mediastack.com/product) oder [newsapi.org](https://newsapi.org/). Beide hätten aber ein niedrigeres Limit an Artikeln pro Tag. Mediastack wäre dabei aber schon interessant, da hier mehr als 7.500 Nachrichtenquellen abgedeckt sein würden. Sollte Currents dies nicht bewerkstelligen können, dann wäre ein Wechsel zu mediastack zu überlegen.
#
# Wenn nicht über APIs, sondern über Webscraping z. B. mittels `Selenium` bzw. Chromedriver/automatisiertem Browser gegangen wird, muss die Legalität nochmals im Einzelfall geprüft werden. Dann muss sich jedoch als "Gegenpart" zur NYT auf eine Zeitung/ein News-Outlet spezialisiert werden (z. B. Washington Times).

# %% [markdown]
# ## Erste Überlegungen zur Datensammlung und Strategie
#
# + Bei der NYT liegt der API-Key vor und es wurde bereits mittels `requests` ein Scraping-Versuch vorgenommen, der erfolgreich war (siehe nachfolgende Codezellen). Hier wurden für die am meisten angesehenen Artikel der letzten 7 Tage Informationen abgegriffen.
#     - Es dürfte einfach möglich sein, hier eine Funktion zu schreiben, indem man 'what' und 'period' ersetzen lässt (vgl. letzte Code-Zelle)
#
# + Für Currents wurde ein API-Zugang per Developer beantragt, ein Key liegt vor, jedoch wurde noch keine genauere Abfrage getestet. Die Dokumentation scheint aber recht gut und aufschlussreich zu sein. Auch hier wird (höchstwahrscheinlich) mit `requests` gearbeitet.
#
# + Es bleibt zu überlegen, ob sich eher auf die "most popular articles" spezialisiert werden sollte, oder ob die Idee, einen Zeitraum festzulegen und hier sozusagen "unabhängig" von Klickzahlen oder Shares über Mail/Social Media eine Analyse durchzuführen, die sich eher auf die behandelten Themen/"Tags" bezieht.
#
# + Es sollte auch bedacht werden, dass im Falle eines Scrapens von Artikeln über einen längeren Zeitraum auf jeden Fall **Paginations-Mechanismen** in etwaige Funktionen eingebaut werden müssen (die NYT weist sogar ausdrücklich darauf hin), auch unabhängig vom genutzten Package (sollten sich hier im Verlauf Änderungen am Wunsch, `requests` zu nutzen, ergeben)
#
# + Datensätze sollten als `Pandas DataFrame` gesichert und nachher als .csv gesichert werden. Dieses Format eignet sich zur Analyse nicht nur mit Python, sondern auch mit R oder gar mit Excel/LibreOffice Calc/Spreadsheets.
#
# + Sollten die API-Zugänge aus verschiedenen Gründen zu "restriktiv" sein, muss sich nochmals über das direkte Scraping der einzelnen Webseiten informiert werden:
#     - NYT: Hier sind einige Dinge gesperrt, die Seite ist sehr tief verschachtelt. Generell sollte hier aber mittels API, den "most popular articles gearbeitet werden können
#     - Currents würde dann wegfallen, da das ja gerade eine API zu **diesem** Zweck ist
#     - Als konservatives Blatt z. B. die Washington Times. Hier ist jedoch nicht genau ersichtlich, ob Scraping per se verboten ist. Robots.txt zeigt einige beschränkte Bereiche (z. B. "guns") und einige Bots sind verboten
#         - Hier wäre es vielleicht (für ein anderes, größeres Projekt) interessant, eine Art Meta-Scraping zu machen und zu schauen, welche Seiten welche Bereiche für Scraping "sperren". Gerade im News-Bereich wäre das sicher interessant, jedoch für dieses Projekt wohl zu ausufernd.

# %%
import requests
from pprint import pprint

# %%
apikey = 'stCPZiKMxcJpce8WKRo8jAamLfs8whRs'

# Top Stories:
# https://developer.nytimes.com/docs/top-stories-product/1/overview
what = "viewed"
period = "7" # aus der dokumentation: ein wert von 1, 7 oder 30 (default == 1; meint: Tage)
query_url = f"https://api.nytimes.com/svc/mostpopular/v2/{what}/{period}.json?api-key={apikey}"

r = requests.get(query_url)
pprint(r.json())

# einfache abfrage für letzte 7 tage scheint zu funktionieren, zieht immer die 20 populärsten artikel nach "views"
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights '
#               'Reserved.',
#  'num_results': 20,
#  'results': [{'abstract': 'The four-time Grand Slam tournament winner wrote on '
#                           'Instagram that she had suffered from bouts of '
#                           'depression since 2018 and that she would “take some '
#                           'time” away from the tennis court.',
#               'adx_keywords': 'Tennis;French Open (Tennis);Mental Health and '
#                               "Disorders;Osaka, Naomi (1997- );Women's Tennis "
#                               'Assn',
#               'asset_id': 100000007790151,
#               'byline': 'By Matthew Futterman',
#               'column': None,
#               'des_facet': ['Tennis',
#                             'French Open (Tennis)',
#                             'Mental Health and Disorders'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007790151,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'Naomi Osaka\xa0acknowledged the crowd '
#                                     'before her first-round match at the '
#                                     'French Open on Sunday.',
#                          'copyright': 'Pete Kiehart for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/05/30/sports/osaka-hfo-web-1/osaka-hfo-web-1-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/05/30/sports/osaka-hfo-web-1/merlin_188509128_06c487d0-e4e9-4d0a-a73b-64424e56a381-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/05/30/sports/osaka-hfo-web-1/merlin_188509128_06c487d0-e4e9-4d0a-a73b-64424e56a381-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'sports',
#               'org_facet': ["Women's Tennis Assn"],
#               'per_facet': ['Osaka, Naomi (1997- )'],
#               'published_date': '2021-05-31',
#               'section': 'Sports',
#               'source': 'New York Times',
#               'subsection': 'Tennis',
#               'title': 'Naomi Osaka Quits the French Open After News '
#                        'Conference Dispute',
#               'type': 'Article',
#               'updated': '2021-06-05 10:27:21',
#               'uri': 'nyt://article/c30033b3-b318-5fa7-9030-23cac2b10b74',
#               'url': 'https://www.nytimes.com/2021/05/31/sports/tennis/naomi-osaka-quits-french-open-depression.html'},
#              {'abstract': 'A new report concedes that much about the observed '
#                           'phenomena remains difficult to explain, including '
#                           'their acceleration, as well as ability to change '
#                           'direction and submerge.',
#               'adx_keywords': 'Unidentified Flying Objects (UFO);Classified '
#                               'Information and State Secrets;Espionage and '
#                               'Intelligence Services;United States Politics '
#                               'and Government;United States Defense and '
#                               'Military Forces;Pilots;Military '
#                               'Aircraft;Extraterrestrial Life;Office of the '
#                               'Director of National Intelligence;United States '
#                               'Navy',
#               'asset_id': 100000007797230,
#               'byline': 'By Julian E. Barnes and Helene Cooper',
#               'column': None,
#               'des_facet': ['Unidentified Flying Objects (UFO)',
#                             'Classified Information and State Secrets',
#                             'Espionage and Intelligence Services',
#                             'United States Politics and Government',
#                             'United States Defense and Military Forces',
#                             'Pilots',
#                             'Military Aircraft',
#                             'Extraterrestrial Life'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007797230,
#               'media': [],
#               'nytdsection': 'u.s.',
#               'org_facet': ['Office of the Director of National Intelligence',
#                             'United States Navy'],
#               'per_facet': [],
#               'published_date': '2021-06-03',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': 'Politics',
#               'title': 'U.S. Finds No Evidence of Alien Technology in Flying '
#                        'Objects, but Can’t Rule It Out, Either',
#               'type': 'Article',
#               'updated': '2021-06-04 13:20:56',
#               'uri': 'nyt://article/5f8d5e14-8f28-50eb-8234-cb6ff39d2d0b',
#               'url': 'https://www.nytimes.com/2021/06/03/us/politics/ufos-sighting-alien-spacecraft-pentagon.html'},
#              {'abstract': 'The star of ‘Mare of Easttown’ is back on the sides '
#                           'of buses. Without airbrushing.',
#               'adx_keywords': 'Content Type: Personal Profile;Actors and '
#                               'Actresses;Television;Winslet, Kate',
#               'asset_id': 100000007786676,
#               'byline': 'By Maureen Dowd',
#               'column': None,
#               'des_facet': ['Content Type: Personal Profile',
#                             'Actors and Actresses',
#                             'Television'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007786676,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'When your dog matches your hair (note '
#                                     'also what appears to be a beer-tab '
#                                     'necklace).',
#                          'copyright': 'Jamie Hawkesworth for The New York '
#                                       'Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/03/fashion/01WITH-KATEWINSLET1/01WITH-KATEWINSLET1-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/03/fashion/01WITH-KATEWINSLET1/01WITH-KATEWINSLET1-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/03/fashion/01WITH-KATEWINSLET1/01WITH-KATEWINSLET1-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'style',
#               'org_facet': [],
#               'per_facet': ['Winslet, Kate'],
#               'published_date': '2021-05-31',
#               'section': 'Style',
#               'source': 'New York Times',
#               'subsection': '',
#               'title': 'Kate Winslet Has No Filter',
#               'type': 'Article',
#               'updated': '2021-06-03 00:10:37',
#               'uri': 'nyt://article/5c518288-b84d-587e-8fc4-b5a38ae9e76e',
#               'url': 'https://www.nytimes.com/2021/05/31/style/mare-of-easttown-kate-winslet.html'},
#              {'abstract': 'A recent graduate in Alpine, Texas, who could not '
#                           'find an affordable lawyer represented herself in '
#                           'court, arguing that school officials made errors in '
#                           'tabulating grade-point averages.',
#               'adx_keywords': 'Grading of Students;Education '
#                               '(Secondary);Awards, Decorations and '
#                               'Honors;Suits and Litigation (Civil);Decisions '
#                               'and Verdicts;Sullivan, Dalee;Alpine (Tex)',
#               'asset_id': 100000007774630,
#               'byline': 'By Rick Rojas',
#               'column': None,
#               'des_facet': ['Grading of Students',
#                             'Education (Secondary)',
#                             'Awards, Decorations and Honors',
#                             'Suits and Litigation (Civil)',
#                             'Decisions and Verdicts'],
#               'eta_id': 0,
#               'geo_facet': ['Alpine (Tex)'],
#               'id': 100000007774630,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'Dalee Sullivan represented herself in '
#                                     'court on Friday, arguing that she '
#                                     'deserved to be ranked higher than No. 3 '
#                                     'in her graduating class.',
#                          'copyright': 'Sarah M Vasquez for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/05/30/us/28texas-student/28texas-student-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/05/30/us/28texas-student/merlin_188442516_7649aea2-206b-4294-bf1e-81b7e91fb4db-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/05/30/us/28texas-student/merlin_188442516_7649aea2-206b-4294-bf1e-81b7e91fb4db-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'u.s.',
#               'org_facet': [],
#               'per_facet': ['Sullivan, Dalee'],
#               'published_date': '2021-05-28',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': '',
#               'title': 'Her High School Said She Ranked Third in Her Class. So '
#                        'She Went to Court.',
#               'type': 'Article',
#               'updated': '2021-06-02 21:59:32',
#               'uri': 'nyt://article/bce9a626-e217-50b6-b43c-3e1c8c3b64d5',
#               'url': 'https://www.nytimes.com/2021/05/28/us/dalee-sullivan-gpa-alpine.html'},
#              {'abstract': 'The Justice Department also said it was changing '
#                           'its policy to bar seizing reporters’ phone and '
#                           'email records in hunts for their sources.',
#               'adx_keywords': 'News Sources, Confidential Status of;Freedom of '
#                               'the Press;Newspapers;E-Mail;United States '
#                               'Politics and Government;Biden, Joseph R '
#                               'Jr;Trump, Donald J;New York Times;Google '
#                               'Inc;Justice Department',
#               'asset_id': 100000007800252,
#               'byline': 'By Charlie Savage and Katie Benner',
#               'column': None,
#               'des_facet': ['News Sources, Confidential Status of',
#                             'Freedom of the Press',
#                             'Newspapers',
#                             'E-Mail',
#                             'United States Politics and Government'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007800252,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'The White House press secretary, Jen '
#                                     'Psaki, said in a statement that no one at '
#                                     'the White House was aware of the gag '
#                                     'order until Friday night.',
#                          'copyright': 'Erin Scott for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/multimedia/05dc-leak-image/merlin_188734170_2dfb19e2-3403-4e44-b86a-9d5ce7557f95-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/multimedia/05dc-leak-image/05dc-leak-image-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/multimedia/05dc-leak-image/05dc-leak-image-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'u.s.',
#               'org_facet': ['New York Times',
#                             'Google Inc',
#                             'Justice Department'],
#               'per_facet': ['Biden, Joseph R Jr', 'Trump, Donald J'],
#               'published_date': '2021-06-05',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': 'Politics',
#               'title': 'White House Disavows Knowledge of Gag Order on Times '
#                        'Leaders in Leak Inquiry',
#               'type': 'Article',
#               'updated': '2021-06-06 00:55:23',
#               'uri': 'nyt://article/7fe65680-23f7-5b52-a9bb-55e35700699d',
#               'url': 'https://www.nytimes.com/2021/06/05/us/politics/biden-gag-order-new-york-times-leak.html'},
#              {'abstract': 'Emails show the increasingly urgent efforts by '
#                           'President Trump and his allies during his last days '
#                           'in office to find some way to undermine, or even '
#                           'nullify, the election results.',
#               'adx_keywords': 'Presidential Election of 2020;United States '
#                               'Politics and Government;Voter Fraud (Election '
#                               'Fraud);Voting Machines;Conspiracy '
#                               'Theories;Rumors and Misinformation;Meadows, '
#                               'Mark R (1959- );Rosen, Jeffrey Adam (1958- '
#                               ');Trump, Donald J;Justice Department',
#               'asset_id': 100000007799406,
#               'byline': 'By Katie Benner',
#               'column': None,
#               'des_facet': ['Presidential Election of 2020',
#                             'United States Politics and Government',
#                             'Voter Fraud (Election Fraud)',
#                             'Voting Machines',
#                             'Conspiracy Theories',
#                             'Rumors and Misinformation'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007799406,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'The newly uncovered emails from Mark '
#                                     'Meadows, then President Donald J. Trump’s '
#                                     'chief of staff, reflect Mr. Trump’s '
#                                     'belief that he could use the Justice '
#                                     'Department to advance his personal '
#                                     'agenda.',
#                          'copyright': 'Erin Scott for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/us/politics/05dc-meadows-1/05dc-meadows-1-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/us/politics/05dc-meadows-1/05dc-meadows-1-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/us/politics/05dc-meadows-1/05dc-meadows-1-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'u.s.',
#               'org_facet': ['Justice Department'],
#               'per_facet': ['Meadows, Mark R (1959- )',
#                             'Rosen, Jeffrey Adam (1958- )',
#                             'Trump, Donald J'],
#               'published_date': '2021-06-05',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': 'Politics',
#               'title': 'Meadows Pressed Justice Dept. to Investigate Election '
#                        'Fraud Claims',
#               'type': 'Article',
#               'updated': '2021-06-06 10:59:59',
#               'uri': 'nyt://article/c3baad37-5f93-595f-8f23-0be4dc875f3b',
#               'url': 'https://www.nytimes.com/2021/06/05/us/politics/mark-meadows-justice-department-election.html'},
#              {'abstract': '“Science doesn’t support prosecution of second '
#                           'graders,” one lawyer said. Still, in New York, '
#                           'children as young as 7 can be charged with a crime.',
#               'adx_keywords': 'Juvenile Delinquency;Law and '
#                               'Legislation;Criminal Justice;Perry, N '
#                               'Nick;Massachusetts;New York State',
#               'asset_id': 100000007707919,
#               'byline': 'By Sarah Maslin Nir',
#               'column': None,
#               'des_facet': ['Juvenile Delinquency',
#                             'Law and Legislation',
#                             'Criminal Justice'],
#               'eta_id': 0,
#               'geo_facet': ['Massachusetts', 'New York State'],
#               'id': 100000007707919,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'An arrest of a child shook tiny Brasher '
#                                     'Falls, a hamlet near the Canadian border, '
#                                     'and may have restarted a push in the '
#                                     'Legislature to change New York’s law.',
#                          'copyright': 'Malik Rainey for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/05/03/nyregion/00NYJUVENILE01/merlin_187237425_b2e2e261-a32b-4790-8ed5-a93150b88e84-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/05/03/nyregion/00NYJUVENILE01/merlin_187237425_b2e2e261-a32b-4790-8ed5-a93150b88e84-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/05/03/nyregion/00NYJUVENILE01/merlin_187237425_b2e2e261-a32b-4790-8ed5-a93150b88e84-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'new york',
#               'org_facet': [],
#               'per_facet': ['Perry, N Nick'],
#               'published_date': '2021-06-03',
#               'section': 'New York',
#               'source': 'New York Times',
#               'subsection': '',
#               'title': 'A 7-Year-Old Was Accused of Rape. Is Arresting Him the '
#                        'Answer?',
#               'type': 'Article',
#               'updated': '2021-06-04 11:47:22',
#               'uri': 'nyt://article/bb711559-3a9c-5005-abca-9cdd1da62e57',
#               'url': 'https://www.nytimes.com/2021/06/03/nyregion/rape-arrest-7-year-old-boy.html'},
#              {'abstract': 'Schools and the entertainment industry, which help '
#                           'shape what is history and what is forgotten, must '
#                           'portray the burden of racism in our nation.\xa0',
#               'adx_keywords': 'Tulsa Race Riot (1921);History (Academic '
#                               'Subject);Education (K-12);Black '
#                               'People;Discrimination;Whites;Tulsa '
#                               '(Okla);United States',
#               'asset_id': 100000007794478,
#               'byline': 'By Tom Hanks',
#               'column': None,
#               'des_facet': ['Tulsa Race Riot (1921)',
#                             'History (Academic Subject)',
#                             'Education (K-12)',
#                             'Black People',
#                             'Discrimination',
#                             'Whites'],
#               'eta_id': 0,
#               'geo_facet': ['Tulsa (Okla)', 'United States'],
#               'id': 100000007794478,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': '&ldquo;Falling Awake,&rdquo; a 2018 work '
#                                     'by Richard Finkelstein.',
#                          'copyright': 'Richard Finkelstein/Robert Mann Gallery',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/06/opinion/00hanksNew/00hanksNew-thumbStandard-v2.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/06/opinion/00hanksNew/00hanksNew-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/06/opinion/00hanksNew/00hanksNew-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'opinion',
#               'org_facet': [],
#               'per_facet': [],
#               'published_date': '2021-06-04',
#               'section': 'Opinion',
#               'source': 'New York Times',
#               'subsection': '',
#               'title': 'Tom Hanks: You Should Learn the Truth About the Tulsa '
#                        'Race Massacre',
#               'type': 'Article',
#               'updated': '2021-06-05 15:43:48',
#               'uri': 'nyt://article/b48a69e1-1237-5d1a-8044-065bea4a15a0',
#               'url': 'https://www.nytimes.com/2021/06/04/opinion/tom-hanks-tulsa-race-massacre-history.html'},
#              {'abstract': 'Scientists were alarmed by blood clots possibly '
#                           'linked to the J&J vaccine. Some women wondered if '
#                           'there shouldn’t be more concern about oral '
#                           'contraceptives.',
#               'adx_keywords': 'your-feed-science;Blood Clots;Women and '
#                               'Girls;Estrogen;Birth Control and Family '
#                               'Planning;Lungs;Vaccination and '
#                               'Immunization;Social Media;Johnson & '
#                               'Johnson;Twitter',
#               'asset_id': 100000007717804,
#               'byline': 'By Apoorva Mandavilli',
#               'column': None,
#               'des_facet': ['your-feed-science',
#                             'Blood Clots',
#                             'Women and Girls',
#                             'Estrogen',
#                             'Birth Control and Family Planning',
#                             'Lungs',
#                             'Vaccination and Immunization',
#                             'Social Media'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007717804,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'Kelly Tyrrell, an ultramarathon runner in '
#                                     'Madison, Wis., was advised to stop taking '
#                                     'estrogen after blood clots were '
#                                     'discovered in her lungs.\xa0',
#                          'copyright': 'Lauren Justice for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/05/28/science/00VIRUS-BIRTHCONTROL1/00VIRUS-BIRTHCONTROL1-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/05/28/science/00VIRUS-BIRTHCONTROL1/00VIRUS-BIRTHCONTROL1-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/05/28/science/00VIRUS-BIRTHCONTROL1/00VIRUS-BIRTHCONTROL1-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'health',
#               'org_facet': ['Johnson & Johnson', 'Twitter'],
#               'per_facet': [],
#               'published_date': '2021-05-30',
#               'section': 'Health',
#               'source': 'New York Times',
#               'subsection': '',
#               'title': 'A Vaccine Side Effect Leaves Women Wondering: Why '
#                        'Isn’t the Pill Safer?',
#               'type': 'Article',
#               'updated': '2021-06-04 09:10:53',
#               'uri': 'nyt://article/866d8c81-93e1-58ae-944e-f48c03e8296a',
#               'url': 'https://www.nytimes.com/2021/05/30/health/coronavirus-vaccine-birth-control-clots.html'},
#              {'abstract': 'Global shortages of many goods reflect the '
#                           'disruption of the pandemic combined with decades of '
#                           'companies limiting their inventories.',
#               'adx_keywords': 'Shortages;Factories and '
#                               'Manufacturing;International Trade and World '
#                               'Market;Automobiles;Computer Chips;Shutdowns '
#                               '(Institutional);Ships and '
#                               'Shipping;Stockpiling;Stock Buybacks;United '
#                               'States Economy;Coronavirus (2019-nCoV);Toyota '
#                               'Motor Corp',
#               'asset_id': 100000007746560,
#               'byline': 'By Peter S. Goodman and Niraj Chokshi',
#               'column': None,
#               'des_facet': ['Shortages',
#                             'Factories and Manufacturing',
#                             'International Trade and World Market',
#                             'Automobiles',
#                             'Computer Chips',
#                             'Shutdowns (Institutional)',
#                             'Ships and Shipping',
#                             'Stockpiling',
#                             'Stock Buybacks',
#                             'United States Economy',
#                             'Coronavirus (2019-nCoV)'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007746560,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'The empty shelves at a Target store in '
#                                     'Dallas last June highlight how companies '
#                                     'of all types were unprepared for a '
#                                     'crisis.',
#                          'copyright': 'Nitashia Johnson for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/05/27/business/00Shortages-1/00Shortages-1-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/05/27/business/00Shortages-1/00Shortages-1-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/05/27/business/00Shortages-1/00Shortages-1-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'business',
#               'org_facet': ['Toyota Motor Corp'],
#               'per_facet': [],
#               'published_date': '2021-06-01',
#               'section': 'Business',
#               'source': 'New York Times',
#               'subsection': '',
#               'title': 'How the World Ran Out of Everything',
#               'type': 'Article',
#               'updated': '2021-06-03 07:54:00',
#               'uri': 'nyt://article/2b5eeefe-0332-525c-8222-cf843875d5d1',
#               'url': 'https://www.nytimes.com/2021/06/01/business/coronavirus-global-shortages.html'},
#              {'abstract': 'Naomi Osaka, a superstar in the sport, pulled out '
#                           'of the French Open after she was fined for skipping '
#                           'a news conference. Did it have to end this way?',
#               'adx_keywords': 'French Open (Tennis);Tennis;Depression '
#                               '(Mental);Mental Health and Disorders;Osaka, '
#                               'Naomi (1997- );Navratilova, Martina;Williams, '
#                               'Serena',
#               'asset_id': 100000007790819,
#               'byline': 'By Christopher Clarey',
#               'column': None,
#               'des_facet': ['French Open (Tennis)',
#                             'Tennis',
#                             'Depression (Mental)',
#                             'Mental Health and Disorders'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007790819,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'Naomi Osaka&rsquo;s wave to the French '
#                                     'Open crowd on Sunday proved to be a wave '
#                                     'goodbye.',
#                          'copyright': 'Pete Kiehart for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/02/us/01french-osaka-clarey-new/01french-osaka-clarey-new-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/02/us/01french-osaka-clarey-new/merlin_188509092_11c38100-0841-4e78-84dd-238c29f64cd5-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/02/us/01french-osaka-clarey-new/merlin_188509092_11c38100-0841-4e78-84dd-238c29f64cd5-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'sports',
#               'org_facet': [],
#               'per_facet': ['Osaka, Naomi (1997- )',
#                             'Navratilova, Martina',
#                             'Williams, Serena'],
#               'published_date': '2021-05-31',
#               'section': 'Sports',
#               'source': 'New York Times',
#               'subsection': 'Tennis',
#               'title': 'A Shocking Exit and a Sad Day for Tennis',
#               'type': 'Article',
#               'updated': '2021-06-05 10:27:49',
#               'uri': 'nyt://article/29b78996-a1b8-5564-a587-519631072a1b',
#               'url': 'https://www.nytimes.com/2021/05/31/sports/tennis/french-open-naomi-osaka-quits.html'},
#              {'abstract': 'The judge said the ban was a “failed experiment.” '
#                           'California’s governor called the ruling “a direct '
#                           'threat to public safety.”',
#               'adx_keywords': 'Gun Control;Decisions and Verdicts;Politics and '
#                               'Government;Benitez, Roger;California',
#               'asset_id': 100000007800009,
#               'byline': 'By Mike Ives',
#               'column': None,
#               'des_facet': ['Gun Control',
#                             'Decisions and Verdicts',
#                             'Politics and Government'],
#               'eta_id': 0,
#               'geo_facet': ['California'],
#               'id': 100000007800009,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'Three variations of the AR-15 assault '
#                                     'rifle are displayed at the California '
#                                     'Department of Justice in Sacramento, '
#                                     'Calif.',
#                          'copyright': 'Rich Pedroncelli/Associated Press',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/multimedia/05xp-weapons-ban-image/merlin_185219226_66590191-957c-4808-b272-c6f3873a5dfb-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/multimedia/05xp-weapons-ban-image/merlin_185219226_66590191-957c-4808-b272-c6f3873a5dfb-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/multimedia/05xp-weapons-ban-image/merlin_185219226_66590191-957c-4808-b272-c6f3873a5dfb-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'u.s.',
#               'org_facet': [],
#               'per_facet': ['Benitez, Roger'],
#               'published_date': '2021-06-05',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': '',
#               'title': 'Federal Judge Overturns California’s 32-Year Assault '
#                        'Weapons Ban',
#               'type': 'Article',
#               'updated': '2021-06-05 11:28:54',
#               'uri': 'nyt://article/22af701d-2afe-549a-9f10-1fc77312be79',
#               'url': 'https://www.nytimes.com/2021/06/05/us/california-assault-weapons-ban.html'},
#              {'abstract': 'The push began in the Trump administration and '
#                           'continued under President Biden, and the Justice '
#                           'Department obtained a gag order to keep it from '
#                           'public view.',
#               'adx_keywords': 'News Sources, Confidential Status of;Freedom of '
#                               'the Press;Classified Information and State '
#                               'Secrets;Newspapers;E-Mail;Russian Interference '
#                               'in 2016 US Elections and Ties to Trump '
#                               'Associates;United States Politics and '
#                               'Government;Comey, James B;Biden, Joseph R '
#                               'Jr;Trump, Donald J;New York Times;Justice '
#                               'Department;Google Inc',
#               'asset_id': 100000007799906,
#               'byline': 'By Charlie Savage and Katie Benner',
#               'column': None,
#               'des_facet': ['News Sources, Confidential Status of',
#                             'Freedom of the Press',
#                             'Classified Information and State Secrets',
#                             'Newspapers',
#                             'E-Mail',
#                             'Russian Interference in 2016 US Elections and '
#                             'Ties to Trump Associates',
#                             'United States Politics and Government'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007799906,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'There was no precedent for the government '
#                                     'to impose a gag order on New York Times '
#                                     'personnel as part of a leak '
#                                     'investigation, said David McCraw, a top '
#                                     'lawyer for the newspaper.',
#                          'copyright': 'Zack DeZon for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/04/us/04dc-Times/04dc-Times-thumbStandard-v2.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/04/us/04dc-Times/04dc-Times-mediumThreeByTwo210-v2.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/04/us/04dc-Times/04dc-Times-mediumThreeByTwo440-v2.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'u.s.',
#               'org_facet': ['New York Times',
#                             'Justice Department',
#                             'Google Inc'],
#               'per_facet': ['Comey, James B',
#                             'Biden, Joseph R Jr',
#                             'Trump, Donald J'],
#               'published_date': '2021-06-04',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': 'Politics',
#               'title': 'U.S. Waged Secret Legal Battle to Obtain Emails of 4 '
#                        'Times Reporters',
#               'type': 'Article',
#               'updated': '2021-06-05 13:09:05',
#               'uri': 'nyt://article/946d91aa-0c39-5db1-89a0-8070e1a77a4d',
#               'url': 'https://www.nytimes.com/2021/06/04/us/politics/times-reporter-emails-gag-order-trump-google.html'},
#              {'abstract': '',
#               'adx_keywords': '',
#               'asset_id': 100000007799455,
#               'byline': '',
#               'column': None,
#               'des_facet': [],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007799455,
#               'media': [],
#               'nytdsection': 'sports',
#               'org_facet': [],
#               'per_facet': [],
#               'published_date': '2021-06-06',
#               'section': 'Sports',
#               'source': '',
#               'subsection': '',
#               'title': 'Floyd Mayweather vs. Logan Paul Ends Without a '
#                        'Knockout',
#               'type': 'LegacyCollection',
#               'updated': '2021-06-07 04:48:54',
#               'uri': 'nyt://legacycollection/39799b6d-bd4b-5606-99c5-251e1d4d573b',
#               'url': 'https://www.nytimes.com/live/2021/06/06/sports/floyd-mayweather-logan-paul'},
#              {'abstract': 'Churchill Downs suspended the colt’s Hall of Fame '
#                           'trainer, Bob Baffert, for two years, and the colt '
#                           'faces disqualification as the Derby winner.',
#               'adx_keywords': 'Doping (Sports);Horse Racing;Tests (Drug '
#                               'Use);Jockeys, Drivers and Trainers;Kentucky '
#                               'Derby;Baffert, Bob;Kentucky Horse Racing '
#                               'Commission',
#               'asset_id': 100000007790968,
#               'byline': 'By Joe Drape',
#               'column': None,
#               'des_facet': ['Doping (Sports)',
#                             'Horse Racing',
#                             'Tests (Drug Use)',
#                             'Jockeys, Drivers and Trainers',
#                             'Kentucky Derby'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007790968,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'Medina Spirit, ridden by jockey John '
#                                     'Velazquez, won the 147th running of the '
#                                     'Kentucky Derby in May.',
#                          'copyright': 'Tim Nwachukwu/Getty Images',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/02/sports/02baffert-2/02baffert-2-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/02/sports/02baffert-2/merlin_187179696_864444a1-aee8-41ac-94a6-d59ebd67d9ea-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/02/sports/02baffert-2/merlin_187179696_864444a1-aee8-41ac-94a6-d59ebd67d9ea-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'sports',
#               'org_facet': ['Kentucky Horse Racing Commission'],
#               'per_facet': ['Baffert, Bob'],
#               'published_date': '2021-06-02',
#               'section': 'Sports',
#               'source': 'New York Times',
#               'subsection': 'Horse Racing',
#               'title': 'Positive Drug Test Confirmed for Kentucky Derby Winner '
#                        'Medina Spirit',
#               'type': 'Article',
#               'updated': '2021-06-05 09:55:29',
#               'uri': 'nyt://article/2586f93e-dee9-5b62-ba67-0ecc693bb155',
#               'url': 'https://www.nytimes.com/2021/06/02/sports/horse-racing/kentucky-derby-medina-spirit-baffert.html'},
#              {'abstract': 'Families losing a loved one to the coronavirus now '
#                           'described a surreal, lonely kind of grief, as the '
#                           'threat from the pandemic lessens in the United '
#                           'States.',
#               'adx_keywords': 'Coronavirus (2019-nCoV);Vaccination and '
#                               'Immunization;Funerals and Memorials;Deaths '
#                               '(Fatalities);Centers for Disease Control and '
#                               'Prevention;GoFundMe;Michigan',
#               'asset_id': 100000007773542,
#               'byline': 'By Sarah Mervosh',
#               'column': None,
#               'des_facet': ['Coronavirus (2019-nCoV)',
#                             'Vaccination and Immunization',
#                             'Funerals and Memorials',
#                             'Deaths (Fatalities)'],
#               'eta_id': 0,
#               'geo_facet': ['Michigan'],
#               'id': 100000007773542,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'People gathered for the viewing of Darryl '
#                                     'Preissler, a carpenter who hoped to do '
#                                     'his own woodworking in retirement.',
#                          'copyright': 'Alyssa Schukar for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/05/28/us/00virus-notover-promo/00virus-notover-2-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/05/28/us/00virus-notover-promo/merlin_188360268_1a38fd5d-9792-4d1a-8fb8-04c29757d4d0-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/05/28/us/00virus-notover-promo/merlin_188360268_1a38fd5d-9792-4d1a-8fb8-04c29757d4d0-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'u.s.',
#               'org_facet': ['Centers for Disease Control and Prevention',
#                             'GoFundMe'],
#               'per_facet': [],
#               'published_date': '2021-05-31',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': '',
#               'title': 'The Pandemic in the U.S. Has Vastly Improved. For '
#                        'These Families, the Worst Has Just Begun.',
#               'type': 'Article',
#               'updated': '2021-06-03 12:26:21',
#               'uri': 'nyt://article/ae0559f0-a850-55e5-9b73-80745a3a8695',
#               'url': 'https://www.nytimes.com/2021/05/31/us/coronavirus-deaths-vaccine.html'},
#              {'abstract': 'Retired Army Lt. Col. Barnard Kemter was speaking '
#                           'at an American Legion service in Hudson, Ohio, on '
#                           'Monday when he was intentionally silenced.',
#               'adx_keywords': 'Memorial Day;Black People;Race and '
#                               'Ethnicity;Civil War (US) (1861-65);Slavery '
#                               '(Historical);Kemter, Barnard;American '
#                               'Legion;Hudson (Ohio);Ohio',
#               'asset_id': 100000007797677,
#               'byline': 'By Neil Vigdor',
#               'column': None,
#               'des_facet': ['Memorial Day',
#                             'Black People',
#                             'Race and Ethnicity',
#                             'Civil War (US) (1861-65)',
#                             'Slavery (Historical)'],
#               'eta_id': 0,
#               'geo_facet': ['Hudson (Ohio)', 'Ohio'],
#               'id': 100000007797677,
#               'media': [],
#               'nytdsection': 'u.s.',
#               'org_facet': ['American Legion'],
#               'per_facet': ['Kemter, Barnard'],
#               'published_date': '2021-06-03',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': '',
#               'title': 'A Veteran Tried to Credit Black Americans on Memorial '
#                        'Day. His Mic Got Muted.',
#               'type': 'Article',
#               'updated': '2021-06-04 16:17:38',
#               'uri': 'nyt://article/2cf95801-7aa3-5349-9cc5-1d9bf4c66c70',
#               'url': 'https://www.nytimes.com/2021/06/03/us/american-legion-ohio-mic-cut-speech.html'},
#              {'abstract': 'The name pays tribute to Harry’s mother, Diana, '
#                           'Princess of Wales, and grandmother, Queen Elizabeth '
#                           'II, after a year of estrangement between the couple '
#                           'and the royal family.',
#               'adx_keywords': 'Royal Families;Harry, Duke of Sussex;Markle, '
#                               'Meghan;Mountbatten-Windsor, Lilibet Diana;Great '
#                               'Britain',
#               'asset_id': 100000007800842,
#               'byline': 'By Mark Landler',
#               'column': None,
#               'des_facet': ['Royal Families'],
#               'eta_id': 0,
#               'geo_facet': ['Great Britain'],
#               'id': 100000007800842,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'Meghan, the Duchess of Sussex, and Prince '
#                                     'Harry in South Africa in 2019.',
#                          'copyright': 'Michele Spatari/Agence France-Presse — '
#                                       'Getty Images',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/06/world/06ROYALS-BABY/06ROYALS-BABY-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/06/world/06ROYALS-BABY/merlin_187285155_c2f987d4-ae40-4c64-8fd8-4644824e58d3-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/06/world/06ROYALS-BABY/merlin_187285155_c2f987d4-ae40-4c64-8fd8-4644824e58d3-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'world',
#               'org_facet': [],
#               'per_facet': ['Harry, Duke of Sussex',
#                             'Markle, Meghan',
#                             'Mountbatten-Windsor, Lilibet Diana'],
#               'published_date': '2021-06-06',
#               'section': 'World',
#               'source': 'New York Times',
#               'subsection': 'Europe',
#               'title': 'Harry and Meghan Announce Birth of Second Baby, '
#                        'Lilibet Diana',
#               'type': 'Article',
#               'updated': '2021-06-07 00:37:54',
#               'uri': 'nyt://article/db960029-4564-5303-ae87-297e2ce3d2fb',
#               'url': 'https://www.nytimes.com/2021/06/06/world/europe/harry-meghan-lilibet-diana.html'},
#              {'abstract': 'The former president had heard from friends that '
#                           'the site was making him look small and irrelevant, '
#                           'according to a person familiar with his thinking.',
#               'adx_keywords': 'Blogs and Blogging (Internet);Politics and '
#                               'Government;Social Media;Trump, Donald J',
#               'asset_id': 100000007794942,
#               'byline': 'By Annie Karni',
#               'column': None,
#               'des_facet': ['Blogs and Blogging (Internet)',
#                             'Politics and Government',
#                             'Social Media'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007794942,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'Former President Donald J. Trump shut '
#                                     'down a blog he had started just a month '
#                                     'ago.',
#                          'copyright': 'Oliver Contreras for The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/02/us/02new-washington-briefing-trump-blog/02new-washington-briefing-trump-blog-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/02/us/02new-washington-briefing-trump-blog/merlin_182250273_4617ab8a-0d98-40ec-a78c-9104e3c2bc80-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/02/us/02new-washington-briefing-trump-blog/merlin_182250273_4617ab8a-0d98-40ec-a78c-9104e3c2bc80-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'u.s.',
#               'org_facet': [],
#               'per_facet': ['Trump, Donald J'],
#               'published_date': '2021-06-02',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': 'Politics',
#               'title': 'Trump shuts down his blog, frustrated by its low '
#                        'readership.',
#               'type': 'Article',
#               'updated': '2021-06-03 11:14:42',
#               'uri': 'nyt://article/be4a8bf7-6238-529b-9803-37443b745456',
#               'url': 'https://www.nytimes.com/2021/06/02/us/politics/trump-shuts-down-blog.html'},
#              {'abstract': 'The former president spoke on Saturday to the North '
#                           'Carolina Republican convention as he resumes '
#                           'political speeches and rallies.',
#               'adx_keywords': 'Rumors and Misinformation;Voter Fraud (Election '
#                               'Fraud);Storming of the US Capitol (Jan, '
#                               '2021);Presidential Election of 2020;United '
#                               'States Politics and Government;Trump, Donald '
#                               'J;Republican Party',
#               'asset_id': 100000007798631,
#               'byline': 'By Annie Karni and Maggie Haberman',
#               'column': None,
#               'des_facet': ['Rumors and Misinformation',
#                             'Voter Fraud (Election Fraud)',
#                             'Storming of the US Capitol (Jan, 2021)',
#                             'Presidential Election of 2020',
#                             'United States Politics and Government'],
#               'eta_id': 0,
#               'geo_facet': [],
#               'id': 100000007798631,
#               'media': [{'approved_for_syndication': 1,
#                          'caption': 'After Donald J. Trump’s speech on '
#                                     'Saturday night in North Carolina, his '
#                                     'first post-presidential rally is '
#                                     'scheduled for later in June.',
#                          'copyright': 'Erin Schaff/The New York Times',
#                          'media-metadata': [{'format': 'Standard Thumbnail',
#                                              'height': 75,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/us/politics/05trump-1/05trump-1-thumbStandard.jpg',
#                                              'width': 75},
#                                             {'format': 'mediumThreeByTwo210',
#                                              'height': 140,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/us/politics/05trump-1/merlin_184399692_ca1c8b86-93e3-4631-9613-c61f00b07fd7-mediumThreeByTwo210.jpg',
#                                              'width': 210},
#                                             {'format': 'mediumThreeByTwo440',
#                                              'height': 293,
#                                              'url': 'https://static01.nyt.com/images/2021/06/05/us/politics/05trump-1/merlin_184399692_ca1c8b86-93e3-4631-9613-c61f00b07fd7-mediumThreeByTwo440.jpg',
#                                              'width': 440}],
#                          'subtype': 'photo',
#                          'type': 'image'}],
#               'nytdsection': 'u.s.',
#               'org_facet': ['Republican Party'],
#               'per_facet': ['Trump, Donald J'],
#               'published_date': '2021-06-05',
#               'section': 'U.S.',
#               'source': 'New York Times',
#               'subsection': 'Politics',
#               'title': 'At Once Diminished and Dominating, Trump Begins His '
#                        'Next Act',
#               'type': 'Article',
#               'updated': '2021-06-06 12:32:34',
#               'uri': 'nyt://article/426a491e-196d-53c4-a612-02a2ee43d034',
#               'url': 'https://www.nytimes.com/2021/06/05/us/politics/donald-trump-republican-convention-speech.html'}],
#  'status': 'OK'}
